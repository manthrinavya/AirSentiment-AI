# %% [markdown]
# # 01 — Preprocessing and Classical TF-IDF
# Run the project scripts from the notebook or inspect their output.

# %%
import os, sys
sys.path.append(os.path.abspath('..'))
from src.preprocessing import main as preprocess
preprocess()

# %%
from src.classical_model import main as train_classical
train_classical()
