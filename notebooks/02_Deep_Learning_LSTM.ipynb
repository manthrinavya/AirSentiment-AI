# %% [markdown]
# # 02 — Deep Learning LSTM
# Train the Embedding + LSTM sentiment classifier.

# %%
import os, sys
sys.path.append(os.path.abspath('..'))
from src.lstm_model import main as train_lstm
train_lstm()

# %%
from src.evaluation import main as evaluate
evaluate()
